# %% [markdown]
# <a href="https://colab.research.google.com/github/leandrofilho07/FutPythonTrader/blob/main/Nova_Base_de_Dados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Importando as Bibliotecas

# %%
#importando bibliotecas
import pandas as pd
import requests 
from google.colab import data_table
data_table.enable_dataframe_formatter()
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Importando a Base de Dados

# %%
# England Premier League	
# 2020/2021
url1 = "https://api.football-data-api.com/league-matches?key=20e2d4aa7479a657c52935c4a743a626941b0a1f41b12156642dd7b62d893145&season_id=4759"	
# 2021/2022
url2 = "https://api.football-data-api.com/league-matches?key=20e2d4aa7479a657c52935c4a743a626941b0a1f41b12156642dd7b62d893145&season_id=6135"
# 2022/2023
url3 = "https://api.football-data-api.com/league-matches?key=20e2d4aa7479a657c52935c4a743a626941b0a1f41b12156642dd7b62d893145&season_id=7704"
data1 = requests.get(url1)
resp1 = data1.json()
resp1 = data1.json()['data']
df1 = pd.DataFrame.from_dict(resp1)
df1['League'] = "England Premier League"	
data2 = requests.get(url2)
resp2 = data2.json()
resp2 = data2.json()['data']
df2 = pd.DataFrame.from_dict(resp2)
df2['League'] = "England Premier League"	
data3 = requests.get(url3)
resp3 = data3.json()
resp3 = data3.json()['data']
df3 = pd.DataFrame.from_dict(resp3)
df3['League'] = "England Premier League"	

# Organizando o DataFrame 01
df1 = df1[['League','season','status','date_unix','game_week','home_name','away_name','odds_ft_1','odds_ft_x','odds_ft_2','homeGoalCount','awayGoalCount','totalGoalCount','homeGoals','awayGoals','odds_ft_over05','odds_ft_over15','odds_ft_over25','odds_btts_yes','odds_btts_no','odds_1st_half_over05','odds_1st_half_under05','ht_goals_team_a','ht_goals_team_b','HTGoalCount']]
df1.columns = ['League','Season','Status','Date','Rodada','Home','Away','Odds_H','Odds_D','Odds_A','FT_Goals_H','FT_Goals_A','FT_TotalGoals','Goals_H_Minutes','Goals_A_Minutes','FT_Odds_Over05','FT_Odds_Over15','FT_Odds_Over25','Odds_BTTS_Yes','Odds_BTTS_No','HT_Odds_Over05','HT_Odds_Under05','HT_Goals_H','HT_Goals_A','HT_TotalGoals']
df1 = df1.dropna()
df1['Date'] = pd.to_datetime(df1['Date'], unit='s') - pd.DateOffset(hours=3)
df1 = df1.sort_values(['Date'])
flt = df1.Status == 'complete'
df1 = df1[flt]
df1 = df1[['League','Season','Date','Home','Away','Odds_H','Odds_D','Odds_A','HT_Odds_Over05','FT_Odds_Over05','FT_Odds_Over15','FT_Odds_Over25','Odds_BTTS_Yes','Odds_BTTS_No','HT_Goals_H','HT_Goals_A','HT_TotalGoals','FT_Goals_H','FT_Goals_A','FT_TotalGoals','Goals_H_Minutes','Goals_A_Minutes']]
df1.reset_index(inplace=True, drop=True)
df1.index = df1.index.set_names(['Nº do Jogo'])
df1 = df1.rename(index=lambda x: x + 1)
df1.to_excel("Inglaterra_01_2020_2021.xlsx", encoding='utf-8', index=False)

# Organizando o DataFrame 02
df2 = df2[['League','season','status','date_unix','game_week','home_name','away_name','odds_ft_1','odds_ft_x','odds_ft_2','homeGoalCount','awayGoalCount','totalGoalCount','homeGoals','awayGoals','odds_ft_over05','odds_ft_over15','odds_ft_over25','odds_btts_yes','odds_btts_no','odds_1st_half_over05','odds_1st_half_under05','ht_goals_team_a','ht_goals_team_b','HTGoalCount']]
df2.columns = ['League','Season','Status','Date','Rodada','Home','Away','Odds_H','Odds_D','Odds_A','FT_Goals_H','FT_Goals_A','FT_TotalGoals','Goals_H_Minutes','Goals_A_Minutes','FT_Odds_Over05','FT_Odds_Over15','FT_Odds_Over25','Odds_BTTS_Yes','Odds_BTTS_No','HT_Odds_Over05','HT_Odds_Under05','HT_Goals_H','HT_Goals_A','HT_TotalGoals']
df2 = df2.dropna()
df2['Date'] = pd.to_datetime(df2['Date'], unit='s') - pd.DateOffset(hours=3)
df2 = df2.sort_values(['Date'])
flt = df2.Status == 'complete'
df2 = df2[flt]
df2 = df2[['League','Season','Date','Home','Away','Odds_H','Odds_D','Odds_A','HT_Odds_Over05','FT_Odds_Over05','FT_Odds_Over15','FT_Odds_Over25','Odds_BTTS_Yes','Odds_BTTS_No','HT_Goals_H','HT_Goals_A','HT_TotalGoals','FT_Goals_H','FT_Goals_A','FT_TotalGoals','Goals_H_Minutes','Goals_A_Minutes']]
df2.reset_index(inplace=True, drop=True)
df2.index = df2.index.set_names(['Nº do Jogo'])
df2 = df2.rename(index=lambda x: x + 1)
df2.to_excel("Inglaterra_01_2021_2022.xlsx", encoding='utf-8', index=False)

# Organizando o DataFrame 03
df3 = df3[['League','season','status','date_unix','game_week','home_name','away_name','odds_ft_1','odds_ft_x','odds_ft_2','homeGoalCount','awayGoalCount','totalGoalCount','homeGoals','awayGoals','odds_ft_over05','odds_ft_over15','odds_ft_over25','odds_btts_yes','odds_btts_no','odds_1st_half_over05','odds_1st_half_under05','ht_goals_team_a','ht_goals_team_b','HTGoalCount']]
df3.columns = ['League','Season','Status','Date','Rodada','Home','Away','Odds_H','Odds_D','Odds_A','FT_Goals_H','FT_Goals_A','FT_TotalGoals','Goals_H_Minutes','Goals_A_Minutes','FT_Odds_Over05','FT_Odds_Over15','FT_Odds_Over25','Odds_BTTS_Yes','Odds_BTTS_No','HT_Odds_Over05','HT_Odds_Under05','HT_Goals_H','HT_Goals_A','HT_TotalGoals']
df3 = df3.dropna()
df3['Date'] = pd.to_datetime(df3['Date'], unit='s') - pd.DateOffset(hours=3)
df3 = df3.sort_values(['Date'])
flt = df3.Status == 'complete'
df3 = df3[flt]
df3 = df3[['League','Season','Date','Home','Away','Odds_H','Odds_D','Odds_A','HT_Odds_Over05','FT_Odds_Over05','FT_Odds_Over15','FT_Odds_Over25','Odds_BTTS_Yes','Odds_BTTS_No','HT_Goals_H','HT_Goals_A','HT_TotalGoals','FT_Goals_H','FT_Goals_A','FT_TotalGoals','Goals_H_Minutes','Goals_A_Minutes']]
df3.reset_index(inplace=True, drop=True)
df3.index = df3.index.set_names(['Nº do Jogo'])
df3 = df3.rename(index=lambda x: x + 1)
df3.to_excel("Inglaterra_01_2022_2023.xlsx", encoding='utf-8', index=False)

# Unindo os DataFrames
df_ING1 = [df1,df2,df3]
df_ING1 = pd.concat(df_ING1)

# %%
# England Championship	
# 2020/2021
url1 = "https://api.football-data-api.com/league-matches?key=20e2d4aa7479a657c52935c4a743a626941b0a1f41b12156642dd7b62d893145&season_id=4912"	
# 2021/2022
url2 = "https://api.football-data-api.com/league-matches?key=20e2d4aa7479a657c52935c4a743a626941b0a1f41b12156642dd7b62d893145&season_id=6089"
# 2022/2023
url3 = "https://api.football-data-api.com/league-matches?key=20e2d4aa7479a657c52935c4a743a626941b0a1f41b12156642dd7b62d893145&season_id=7593"
data1 = requests.get(url1)
resp1 = data1.json()
resp1 = data1.json()['data']
df1 = pd.DataFrame.from_dict(resp1)
df1['League'] = "England Championship"	
data2 = requests.get(url2)
resp2 = data2.json()
resp2 = data2.json()['data']
df2 = pd.DataFrame.from_dict(resp2)
df2['League'] = "England Championship"	
data3 = requests.get(url3)
resp3 = data3.json()
resp3 = data3.json()['data']
df3 = pd.DataFrame.from_dict(resp3)
df3['League'] = "England Championship"	

# Organizando o DataFrame 01
df1 = df1[['League','season','status','date_unix','game_week','home_name','away_name','odds_ft_1','odds_ft_x','odds_ft_2','homeGoalCount','awayGoalCount','totalGoalCount','homeGoals','awayGoals','odds_ft_over05','odds_ft_over15','odds_ft_over25','odds_btts_yes','odds_btts_no','odds_1st_half_over05','odds_1st_half_under05','ht_goals_team_a','ht_goals_team_b','HTGoalCount']]
df1.columns = ['League','Season','Status','Date','Rodada','Home','Away','Odds_H','Odds_D','Odds_A','FT_Goals_H','FT_Goals_A','FT_TotalGoals','Goals_H_Minutes','Goals_A_Minutes','FT_Odds_Over05','FT_Odds_Over15','FT_Odds_Over25','Odds_BTTS_Yes','Odds_BTTS_No','HT_Odds_Over05','HT_Odds_Under05','HT_Goals_H','HT_Goals_A','HT_TotalGoals']
df1 = df1.dropna()
df1['Date'] = pd.to_datetime(df1['Date'], unit='s') - pd.DateOffset(hours=3)
df1 = df1.sort_values(['Date'])
flt = df1.Status == 'complete'
df1 = df1[flt]
df1 = df1[['League','Season','Date','Home','Away','Odds_H','Odds_D','Odds_A','HT_Odds_Over05','FT_Odds_Over05','FT_Odds_Over15','FT_Odds_Over25','Odds_BTTS_Yes','Odds_BTTS_No','HT_Goals_H','HT_Goals_A','HT_TotalGoals','FT_Goals_H','FT_Goals_A','FT_TotalGoals','Goals_H_Minutes','Goals_A_Minutes']]
df1.reset_index(inplace=True, drop=True)
df1.index = df1.index.set_names(['Nº do Jogo'])
df1 = df1.rename(index=lambda x: x + 1)
df1.to_excel("Inglaterra_02_2020_2021.xlsx", encoding='utf-8', index=False)

# Organizando o DataFrame 02
df2 = df2[['League','season','status','date_unix','game_week','home_name','away_name','odds_ft_1','odds_ft_x','odds_ft_2','homeGoalCount','awayGoalCount','totalGoalCount','homeGoals','awayGoals','odds_ft_over05','odds_ft_over15','odds_ft_over25','odds_btts_yes','odds_btts_no','odds_1st_half_over05','odds_1st_half_under05','ht_goals_team_a','ht_goals_team_b','HTGoalCount']]
df2.columns = ['League','Season','Status','Date','Rodada','Home','Away','Odds_H','Odds_D','Odds_A','FT_Goals_H','FT_Goals_A','FT_TotalGoals','Goals_H_Minutes','Goals_A_Minutes','FT_Odds_Over05','FT_Odds_Over15','FT_Odds_Over25','Odds_BTTS_Yes','Odds_BTTS_No','HT_Odds_Over05','HT_Odds_Under05','HT_Goals_H','HT_Goals_A','HT_TotalGoals']
df2 = df2.dropna()
df2['Date'] = pd.to_datetime(df2['Date'], unit='s') - pd.DateOffset(hours=3)
df2 = df2.sort_values(['Date'])
flt = df2.Status == 'complete'
df2 = df2[flt]
df2 = df2[['League','Season','Date','Home','Away','Odds_H','Odds_D','Odds_A','HT_Odds_Over05','FT_Odds_Over05','FT_Odds_Over15','FT_Odds_Over25','Odds_BTTS_Yes','Odds_BTTS_No','HT_Goals_H','HT_Goals_A','HT_TotalGoals','FT_Goals_H','FT_Goals_A','FT_TotalGoals','Goals_H_Minutes','Goals_A_Minutes']]
df2.reset_index(inplace=True, drop=True)
df2.index = df2.index.set_names(['Nº do Jogo'])
df2 = df2.rename(index=lambda x: x + 1)
df2.to_excel("Inglaterra_02_2021_2022.xlsx", encoding='utf-8', index=False)

# Organizando o DataFrame 03
df3 = df3[['League','season','status','date_unix','game_week','home_name','away_name','odds_ft_1','odds_ft_x','odds_ft_2','homeGoalCount','awayGoalCount','totalGoalCount','homeGoals','awayGoals','odds_ft_over05','odds_ft_over15','odds_ft_over25','odds_btts_yes','odds_btts_no','odds_1st_half_over05','odds_1st_half_under05','ht_goals_team_a','ht_goals_team_b','HTGoalCount']]
df3.columns = ['League','Season','Status','Date','Rodada','Home','Away','Odds_H','Odds_D','Odds_A','FT_Goals_H','FT_Goals_A','FT_TotalGoals','Goals_H_Minutes','Goals_A_Minutes','FT_Odds_Over05','FT_Odds_Over15','FT_Odds_Over25','Odds_BTTS_Yes','Odds_BTTS_No','HT_Odds_Over05','HT_Odds_Under05','HT_Goals_H','HT_Goals_A','HT_TotalGoals']
df3 = df3.dropna()
df3['Date'] = pd.to_datetime(df3['Date'], unit='s') - pd.DateOffset(hours=3)
df3 = df3.sort_values(['Date'])
flt = df3.Status == 'complete'
df3 = df3[flt]
df3 = df3[['League','Season','Date','Home','Away','Odds_H','Odds_D','Odds_A','HT_Odds_Over05','FT_Odds_Over05','FT_Odds_Over15','FT_Odds_Over25','Odds_BTTS_Yes','Odds_BTTS_No','HT_Goals_H','HT_Goals_A','HT_TotalGoals','FT_Goals_H','FT_Goals_A','FT_TotalGoals','Goals_H_Minutes','Goals_A_Minutes']]
df3.reset_index(inplace=True, drop=True)
df3.index = df3.index.set_names(['Nº do Jogo'])
df3 = df3.rename(index=lambda x: x + 1)
df3.to_excel("Inglaterra_02_2022_2023.xlsx", encoding='utf-8', index=False)

# Unindo os DataFrames
df_ING2 = [df1,df2,df3]
df_ING2 = pd.concat(df_ING2)

# %%
# Germany Bundesliga	
# 2020/2021
url1 = "https://api.football-data-api.com/league-matches?key=20e2d4aa7479a657c52935c4a743a626941b0a1f41b12156642dd7b62d893145&season_id=4673"	
# 2021/2022
url2 = "https://api.football-data-api.com/league-matches?key=20e2d4aa7479a657c52935c4a743a626941b0a1f41b12156642dd7b62d893145&season_id=6192"
# 2022/2023
url3 = "https://api.football-data-api.com/league-matches?key=20e2d4aa7479a657c52935c4a743a626941b0a1f41b12156642dd7b62d893145&season_id=7664"
data1 = requests.get(url1)
resp1 = data1.json()
resp1 = data1.json()['data']
df1 = pd.DataFrame.from_dict(resp1)
df1['League'] = "Germany Bundesliga"	
data2 = requests.get(url2)
resp2 = data2.json()
resp2 = data2.json()['data']
df2 = pd.DataFrame.from_dict(resp2)
df2['League'] = "Germany Bundesliga"	
data3 = requests.get(url3)
resp3 = data3.json()
resp3 = data3.json()['data']
df3 = pd.DataFrame.from_dict(resp3)
df3['League'] = "Germany Bundesliga"	

# Organizando o DataFrame 01
df1 = df1[['League','season','status','date_unix','game_week','home_name','away_name','odds_ft_1','odds_ft_x','odds_ft_2','homeGoalCount','awayGoalCount','totalGoalCount','homeGoals','awayGoals','odds_ft_over05','odds_ft_over15','odds_ft_over25','odds_btts_yes','odds_btts_no','odds_1st_half_over05','odds_1st_half_under05','ht_goals_team_a','ht_goals_team_b','HTGoalCount']]
df1.columns = ['League','Season','Status','Date','Rodada','Home','Away','Odds_H','Odds_D','Odds_A','FT_Goals_H','FT_Goals_A','FT_TotalGoals','Goals_H_Minutes','Goals_A_Minutes','FT_Odds_Over05','FT_Odds_Over15','FT_Odds_Over25','Odds_BTTS_Yes','Odds_BTTS_No','HT_Odds_Over05','HT_Odds_Under05','HT_Goals_H','HT_Goals_A','HT_TotalGoals']
df1 = df1.dropna()
df1['Date'] = pd.to_datetime(df1['Date'], unit='s') - pd.DateOffset(hours=3)
df1 = df1.sort_values(['Date'])
flt = df1.Status == 'complete'
df1 = df1[flt]
df1 = df1[['League','Season','Date','Home','Away','Odds_H','Odds_D','Odds_A','HT_Odds_Over05','FT_Odds_Over05','FT_Odds_Over15','FT_Odds_Over25','Odds_BTTS_Yes','Odds_BTTS_No','HT_Goals_H','HT_Goals_A','HT_TotalGoals','FT_Goals_H','FT_Goals_A','FT_TotalGoals','Goals_H_Minutes','Goals_A_Minutes']]
df1.reset_index(inplace=True, drop=True)
df1.index = df1.index.set_names(['Nº do Jogo'])
df1 = df1.rename(index=lambda x: x + 1)
df1.to_excel("Alemanha_01_2020_2021.xlsx", encoding='utf-8', index=False)

# Organizando o DataFrame 02
df2 = df2[['League','season','status','date_unix','game_week','home_name','away_name','odds_ft_1','odds_ft_x','odds_ft_2','homeGoalCount','awayGoalCount','totalGoalCount','homeGoals','awayGoals','odds_ft_over05','odds_ft_over15','odds_ft_over25','odds_btts_yes','odds_btts_no','odds_1st_half_over05','odds_1st_half_under05','ht_goals_team_a','ht_goals_team_b','HTGoalCount']]
df2.columns = ['League','Season','Status','Date','Rodada','Home','Away','Odds_H','Odds_D','Odds_A','FT_Goals_H','FT_Goals_A','FT_TotalGoals','Goals_H_Minutes','Goals_A_Minutes','FT_Odds_Over05','FT_Odds_Over15','FT_Odds_Over25','Odds_BTTS_Yes','Odds_BTTS_No','HT_Odds_Over05','HT_Odds_Under05','HT_Goals_H','HT_Goals_A','HT_TotalGoals']
df2 = df2.dropna()
df2['Date'] = pd.to_datetime(df2['Date'], unit='s') - pd.DateOffset(hours=3)
df2 = df2.sort_values(['Date'])
flt = df2.Status == 'complete'
df2 = df2[flt]
df2 = df2[['League','Season','Date','Home','Away','Odds_H','Odds_D','Odds_A','HT_Odds_Over05','FT_Odds_Over05','FT_Odds_Over15','FT_Odds_Over25','Odds_BTTS_Yes','Odds_BTTS_No','HT_Goals_H','HT_Goals_A','HT_TotalGoals','FT_Goals_H','FT_Goals_A','FT_TotalGoals','Goals_H_Minutes','Goals_A_Minutes']]
df2.reset_index(inplace=True, drop=True)
df2.index = df2.index.set_names(['Nº do Jogo'])
df2 = df2.rename(index=lambda x: x + 1)
df2.to_excel("Alemanha_01_2021_2022.xlsx", encoding='utf-8', index=False)

# Organizando o DataFrame 03
df3 = df3[['League','season','status','date_unix','game_week','home_name','away_name','odds_ft_1','odds_ft_x','odds_ft_2','homeGoalCount','awayGoalCount','totalGoalCount','homeGoals','awayGoals','odds_ft_over05','odds_ft_over15','odds_ft_over25','odds_btts_yes','odds_btts_no','odds_1st_half_over05','odds_1st_half_under05','ht_goals_team_a','ht_goals_team_b','HTGoalCount']]
df3.columns = ['League','Season','Status','Date','Rodada','Home','Away','Odds_H','Odds_D','Odds_A','FT_Goals_H','FT_Goals_A','FT_TotalGoals','Goals_H_Minutes','Goals_A_Minutes','FT_Odds_Over05','FT_Odds_Over15','FT_Odds_Over25','Odds_BTTS_Yes','Odds_BTTS_No','HT_Odds_Over05','HT_Odds_Under05','HT_Goals_H','HT_Goals_A','HT_TotalGoals']
df3 = df3.dropna()
df3['Date'] = pd.to_datetime(df3['Date'], unit='s') - pd.DateOffset(hours=3)
df3 = df3.sort_values(['Date'])
flt = df3.Status == 'complete'
df3 = df3[flt]
df3 = df3[['League','Season','Date','Home','Away','Odds_H','Odds_D','Odds_A','HT_Odds_Over05','FT_Odds_Over05','FT_Odds_Over15','FT_Odds_Over25','Odds_BTTS_Yes','Odds_BTTS_No','HT_Goals_H','HT_Goals_A','HT_TotalGoals','FT_Goals_H','FT_Goals_A','FT_TotalGoals','Goals_H_Minutes','Goals_A_Minutes']]
df3.reset_index(inplace=True, drop=True)
df3.index = df3.index.set_names(['Nº do Jogo'])
df3 = df3.rename(index=lambda x: x + 1)
df3.to_excel("Alemanha_01_2022_2023.xlsx", encoding='utf-8', index=False)

# Unindo os DataFrames
df_ALE1 = [df1,df2,df3]
df_ALE1 = pd.concat(df_ALE1)

# %%
# Germany 2. Bundesliga	
# 2020/2021
url1 = "https://api.football-data-api.com/league-matches?key=20e2d4aa7479a657c52935c4a743a626941b0a1f41b12156642dd7b62d893145&season_id=4676"	
# 2021/2022
url2 = "https://api.football-data-api.com/league-matches?key=20e2d4aa7479a657c52935c4a743a626941b0a1f41b12156642dd7b62d893145&season_id=6020"
# 2022/2023
url3 = "https://api.football-data-api.com/league-matches?key=20e2d4aa7479a657c52935c4a743a626941b0a1f41b12156642dd7b62d893145&season_id=7499"
data1 = requests.get(url1)
resp1 = data1.json()
resp1 = data1.json()['data']
df1 = pd.DataFrame.from_dict(resp1)
df1['League'] = "Germany 2. Bundesliga"	
data2 = requests.get(url2)
resp2 = data2.json()
resp2 = data2.json()['data']
df2 = pd.DataFrame.from_dict(resp2)
df2['League'] = "Germany 2. Bundesliga"	
data3 = requests.get(url3)
resp3 = data3.json()
resp3 = data3.json()['data']
df3 = pd.DataFrame.from_dict(resp3)
df3['League'] = "Germany 2. Bundesliga"	

# Organizando o DataFrame 01
df1 = df1[['League','season','status','date_unix','game_week','home_name','away_name','odds_ft_1','odds_ft_x','odds_ft_2','homeGoalCount','awayGoalCount','totalGoalCount','homeGoals','awayGoals','odds_ft_over05','odds_ft_over15','odds_ft_over25','odds_btts_yes','odds_btts_no','odds_1st_half_over05','odds_1st_half_under05','ht_goals_team_a','ht_goals_team_b','HTGoalCount']]
df1.columns = ['League','Season','Status','Date','Rodada','Home','Away','Odds_H','Odds_D','Odds_A','FT_Goals_H','FT_Goals_A','FT_TotalGoals','Goals_H_Minutes','Goals_A_Minutes','FT_Odds_Over05','FT_Odds_Over15','FT_Odds_Over25','Odds_BTTS_Yes','Odds_BTTS_No','HT_Odds_Over05','HT_Odds_Under05','HT_Goals_H','HT_Goals_A','HT_TotalGoals']
df1 = df1.dropna()
df1['Date'] = pd.to_datetime(df1['Date'], unit='s') - pd.DateOffset(hours=3)
df1 = df1.sort_values(['Date'])
flt = df1.Status == 'complete'
df1 = df1[flt]
df1 = df1[['League','Season','Date','Home','Away','Odds_H','Odds_D','Odds_A','HT_Odds_Over05','FT_Odds_Over05','FT_Odds_Over15','FT_Odds_Over25','Odds_BTTS_Yes','Odds_BTTS_No','HT_Goals_H','HT_Goals_A','HT_TotalGoals','FT_Goals_H','FT_Goals_A','FT_TotalGoals','Goals_H_Minutes','Goals_A_Minutes']]
df1.reset_index(inplace=True, drop=True)
df1.index = df1.index.set_names(['Nº do Jogo'])
df1 = df1.rename(index=lambda x: x + 1)
df1.to_excel("Alemanha_02_2020_2021.xlsx", encoding='utf-8', index=False)

# Organizando o DataFrame 02
df2 = df2[['League','season','status','date_unix','game_week','home_name','away_name','odds_ft_1','odds_ft_x','odds_ft_2','homeGoalCount','awayGoalCount','totalGoalCount','homeGoals','awayGoals','odds_ft_over05','odds_ft_over15','odds_ft_over25','odds_btts_yes','odds_btts_no','odds_1st_half_over05','odds_1st_half_under05','ht_goals_team_a','ht_goals_team_b','HTGoalCount']]
df2.columns = ['League','Season','Status','Date','Rodada','Home','Away','Odds_H','Odds_D','Odds_A','FT_Goals_H','FT_Goals_A','FT_TotalGoals','Goals_H_Minutes','Goals_A_Minutes','FT_Odds_Over05','FT_Odds_Over15','FT_Odds_Over25','Odds_BTTS_Yes','Odds_BTTS_No','HT_Odds_Over05','HT_Odds_Under05','HT_Goals_H','HT_Goals_A','HT_TotalGoals']
df2 = df2.dropna()
df2['Date'] = pd.to_datetime(df2['Date'], unit='s') - pd.DateOffset(hours=3)
df2 = df2.sort_values(['Date'])
flt = df2.Status == 'complete'
df2 = df2[flt]
df2 = df2[['League','Season','Date','Home','Away','Odds_H','Odds_D','Odds_A','HT_Odds_Over05','FT_Odds_Over05','FT_Odds_Over15','FT_Odds_Over25','Odds_BTTS_Yes','Odds_BTTS_No','HT_Goals_H','HT_Goals_A','HT_TotalGoals','FT_Goals_H','FT_Goals_A','FT_TotalGoals','Goals_H_Minutes','Goals_A_Minutes']]
df2.reset_index(inplace=True, drop=True)
df2.index = df2.index.set_names(['Nº do Jogo'])
df2 = df2.rename(index=lambda x: x + 1)
df2.to_excel("Alemanha_02_2021_2022.xlsx", encoding='utf-8', index=False)

# Organizando o DataFrame 03
df3 = df3[['League','season','status','date_unix','game_week','home_name','away_name','odds_ft_1','odds_ft_x','odds_ft_2','homeGoalCount','awayGoalCount','totalGoalCount','homeGoals','awayGoals','odds_ft_over05','odds_ft_over15','odds_ft_over25','odds_btts_yes','odds_btts_no','odds_1st_half_over05','odds_1st_half_under05','ht_goals_team_a','ht_goals_team_b','HTGoalCount']]
df3.columns = ['League','Season','Status','Date','Rodada','Home','Away','Odds_H','Odds_D','Odds_A','FT_Goals_H','FT_Goals_A','FT_TotalGoals','Goals_H_Minutes','Goals_A_Minutes','FT_Odds_Over05','FT_Odds_Over15','FT_Odds_Over25','Odds_BTTS_Yes','Odds_BTTS_No','HT_Odds_Over05','HT_Odds_Under05','HT_Goals_H','HT_Goals_A','HT_TotalGoals']
df3 = df3.dropna()
df3['Date'] = pd.to_datetime(df3['Date'], unit='s') - pd.DateOffset(hours=3)
df3 = df3.sort_values(['Date'])
flt = df3.Status == 'complete'
df3 = df3[flt]
df3 = df3[['League','Season','Date','Home','Away','Odds_H','Odds_D','Odds_A','HT_Odds_Over05','FT_Odds_Over05','FT_Odds_Over15','FT_Odds_Over25','Odds_BTTS_Yes','Odds_BTTS_No','HT_Goals_H','HT_Goals_A','HT_TotalGoals','FT_Goals_H','FT_Goals_A','FT_TotalGoals','Goals_H_Minutes','Goals_A_Minutes']]
df3.reset_index(inplace=True, drop=True)
df3.index = df3.index.set_names(['Nº do Jogo'])
df3 = df3.rename(index=lambda x: x + 1)
df3.to_excel("Alemanha_02_2022_2023.xlsx", encoding='utf-8', index=False)

# Unindo os DataFrames
df_ALE2 = [df1,df2,df3]
df_ALE2 = pd.concat(df_ALE2)

# %%
# Unindo Todos os DataFrames
df = [df_ING1,df_ING2,df_ALE1,df_ALE2]
df = pd.concat(df)
df.to_excel("Base_de_Dados.xlsx")

# %%
# England Premier League	
# 2022/2023
url3 = "https://api.football-data-api.com/league-matches?key=20e2d4aa7479a657c52935c4a743a626941b0a1f41b12156642dd7b62d893145&season_id=7704"
data3 = requests.get(url3)
resp3 = data3.json()
resp3 = data3.json()['data']
df3 = pd.DataFrame.from_dict(resp3)
df3['League'] = "England Premier League"	

# Organizando o DataFrame 03
df3 = df3[['League','season','status','date_unix','game_week','home_name','away_name','odds_ft_1','odds_ft_x','odds_ft_2','homeGoalCount','awayGoalCount','totalGoalCount','homeGoals','awayGoals','odds_ft_over05','odds_ft_over15','odds_ft_over25','odds_btts_yes','odds_btts_no','odds_1st_half_over05','odds_1st_half_under05','ht_goals_team_a','ht_goals_team_b','HTGoalCount']]
df3.columns = ['League','Season','Status','Date','Rodada','Home','Away','Odds_H','Odds_D','Odds_A','FT_Goals_H','FT_Goals_A','FT_TotalGoals','Goals_H_Minutes','Goals_A_Minutes','FT_Odds_Over05','FT_Odds_Over15','FT_Odds_Over25','Odds_BTTS_Yes','Odds_BTTS_No','HT_Odds_Over05','HT_Odds_Under05','HT_Goals_H','HT_Goals_A','HT_TotalGoals']
df3 = df3.dropna()
df3['Date'] = pd.to_datetime(df3['Date'], unit='s') - pd.DateOffset(hours=3)
df3 = df3.sort_values(['Date'])
flt = df3.Status == 'complete'
df3 = df3[flt]
df3 = df3[['League','Season','Date','Home','Away','Odds_H','Odds_D','Odds_A','HT_Odds_Over05','FT_Odds_Over05','FT_Odds_Over15','FT_Odds_Over25','Odds_BTTS_Yes','Odds_BTTS_No','HT_Goals_H','HT_Goals_A','HT_TotalGoals','FT_Goals_H','FT_Goals_A','FT_TotalGoals','Goals_H_Minutes','Goals_A_Minutes']]
df3.reset_index(inplace=True, drop=True)
df3.index = df3.index.set_names(['Nº do Jogo'])
df3 = df3.rename(index=lambda x: x + 1)
df3.to_excel("Inglaterra_01_2022_2023.xlsx", encoding='utf-8', index=False)

# England Championship	
# 2022/2023
url3 = "https://api.football-data-api.com/league-matches?key=20e2d4aa7479a657c52935c4a743a626941b0a1f41b12156642dd7b62d893145&season_id=7593"
data3 = requests.get(url3)
resp3 = data3.json()
resp3 = data3.json()['data']
df3 = pd.DataFrame.from_dict(resp3)
df3['League'] = "England Championship"	

# Organizando o DataFrame 03
df3 = df3[['League','season','status','date_unix','game_week','home_name','away_name','odds_ft_1','odds_ft_x','odds_ft_2','homeGoalCount','awayGoalCount','totalGoalCount','homeGoals','awayGoals','odds_ft_over05','odds_ft_over15','odds_ft_over25','odds_btts_yes','odds_btts_no','odds_1st_half_over05','odds_1st_half_under05','ht_goals_team_a','ht_goals_team_b','HTGoalCount']]
df3.columns = ['League','Season','Status','Date','Rodada','Home','Away','Odds_H','Odds_D','Odds_A','FT_Goals_H','FT_Goals_A','FT_TotalGoals','Goals_H_Minutes','Goals_A_Minutes','FT_Odds_Over05','FT_Odds_Over15','FT_Odds_Over25','Odds_BTTS_Yes','Odds_BTTS_No','HT_Odds_Over05','HT_Odds_Under05','HT_Goals_H','HT_Goals_A','HT_TotalGoals']
df3 = df3.dropna()
df3['Date'] = pd.to_datetime(df3['Date'], unit='s') - pd.DateOffset(hours=3)
df3 = df3.sort_values(['Date'])
flt = df3.Status == 'complete'
df3 = df3[flt]
df3 = df3[['League','Season','Date','Home','Away','Odds_H','Odds_D','Odds_A','HT_Odds_Over05','FT_Odds_Over05','FT_Odds_Over15','FT_Odds_Over25','Odds_BTTS_Yes','Odds_BTTS_No','HT_Goals_H','HT_Goals_A','HT_TotalGoals','FT_Goals_H','FT_Goals_A','FT_TotalGoals','Goals_H_Minutes','Goals_A_Minutes']]
df3.reset_index(inplace=True, drop=True)
df3.index = df3.index.set_names(['Nº do Jogo'])
df3 = df3.rename(index=lambda x: x + 1)
df3.to_excel("Inglaterra_02_2022_2023.xlsx", encoding='utf-8', index=False)


# Germany Bundesliga	
# 2022/2023
url3 = "https://api.football-data-api.com/league-matches?key=20e2d4aa7479a657c52935c4a743a626941b0a1f41b12156642dd7b62d893145&season_id=7664"
data3 = requests.get(url3)
resp3 = data3.json()
resp3 = data3.json()['data']
df3 = pd.DataFrame.from_dict(resp3)
df3['League'] = "Germany Bundesliga"	


# Organizando o DataFrame 03
df3 = df3[['League','season','status','date_unix','game_week','home_name','away_name','odds_ft_1','odds_ft_x','odds_ft_2','homeGoalCount','awayGoalCount','totalGoalCount','homeGoals','awayGoals','odds_ft_over05','odds_ft_over15','odds_ft_over25','odds_btts_yes','odds_btts_no','odds_1st_half_over05','odds_1st_half_under05','ht_goals_team_a','ht_goals_team_b','HTGoalCount']]
df3.columns = ['League','Season','Status','Date','Rodada','Home','Away','Odds_H','Odds_D','Odds_A','FT_Goals_H','FT_Goals_A','FT_TotalGoals','Goals_H_Minutes','Goals_A_Minutes','FT_Odds_Over05','FT_Odds_Over15','FT_Odds_Over25','Odds_BTTS_Yes','Odds_BTTS_No','HT_Odds_Over05','HT_Odds_Under05','HT_Goals_H','HT_Goals_A','HT_TotalGoals']
df3 = df3.dropna()
df3['Date'] = pd.to_datetime(df3['Date'], unit='s') - pd.DateOffset(hours=3)
df3 = df3.sort_values(['Date'])
flt = df3.Status == 'complete'
df3 = df3[flt]
df3 = df3[['League','Season','Date','Home','Away','Odds_H','Odds_D','Odds_A','HT_Odds_Over05','FT_Odds_Over05','FT_Odds_Over15','FT_Odds_Over25','Odds_BTTS_Yes','Odds_BTTS_No','HT_Goals_H','HT_Goals_A','HT_TotalGoals','FT_Goals_H','FT_Goals_A','FT_TotalGoals','Goals_H_Minutes','Goals_A_Minutes']]
df3.reset_index(inplace=True, drop=True)
df3.index = df3.index.set_names(['Nº do Jogo'])
df3 = df3.rename(index=lambda x: x + 1)
df3.to_excel("Alemanha_01_2022_2023.xlsx", encoding='utf-8', index=False)

# Germany 2. Bundesliga	
# 2022/2023
url3 = "https://api.football-data-api.com/league-matches?key=20e2d4aa7479a657c52935c4a743a626941b0a1f41b12156642dd7b62d893145&season_id=7499"
data3 = requests.get(url3)
resp3 = data3.json()
resp3 = data3.json()['data']
df3 = pd.DataFrame.from_dict(resp3)
df3['League'] = "Germany 2. Bundesliga"	


# Organizando o DataFrame 03
df3 = df3[['League','season','status','date_unix','game_week','home_name','away_name','odds_ft_1','odds_ft_x','odds_ft_2','homeGoalCount','awayGoalCount','totalGoalCount','homeGoals','awayGoals','odds_ft_over05','odds_ft_over15','odds_ft_over25','odds_btts_yes','odds_btts_no','odds_1st_half_over05','odds_1st_half_under05','ht_goals_team_a','ht_goals_team_b','HTGoalCount']]
df3.columns = ['League','Season','Status','Date','Rodada','Home','Away','Odds_H','Odds_D','Odds_A','FT_Goals_H','FT_Goals_A','FT_TotalGoals','Goals_H_Minutes','Goals_A_Minutes','FT_Odds_Over05','FT_Odds_Over15','FT_Odds_Over25','Odds_BTTS_Yes','Odds_BTTS_No','HT_Odds_Over05','HT_Odds_Under05','HT_Goals_H','HT_Goals_A','HT_TotalGoals']
df3 = df3.dropna()
df3['Date'] = pd.to_datetime(df3['Date'], unit='s') - pd.DateOffset(hours=3)
df3 = df3.sort_values(['Date'])
flt = df3.Status == 'complete'
df3 = df3[flt]
df3 = df3[['League','Season','Date','Home','Away','Odds_H','Odds_D','Odds_A','HT_Odds_Over05','FT_Odds_Over05','FT_Odds_Over15','FT_Odds_Over25','Odds_BTTS_Yes','Odds_BTTS_No','HT_Goals_H','HT_Goals_A','HT_TotalGoals','FT_Goals_H','FT_Goals_A','FT_TotalGoals','Goals_H_Minutes','Goals_A_Minutes']]
df3.reset_index(inplace=True, drop=True)
df3.index = df3.index.set_names(['Nº do Jogo'])
df3 = df3.rename(index=lambda x: x + 1)
df3.to_excel("Alemanha_02_2022_2023.xlsx", encoding='utf-8', index=False)
